# %% [markdown]
# <a href="https://colab.research.google.com/github/luanbezerra/climate-impact-predator-prey-populations/blob/main/P2_metodos_Lotka_Volterra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **O impacto do aquecimento global na população de lobos e alces em Isle Royale National Park** 🔍

# %% [markdown]
# Alunos 📚:
#
# Caio Rocha Calado (crc@cin.ufpe.br)
#
# Luan Bezerra Coelho (lbc2@cin.ufpe.br)
#
# Mateus Araújo Neves (man2@cin.ufpe.br)
#
# Péricles Ferreira Sardinha (pfs@cin.ufpe.br)

# %% [markdown]
# # Resumo <a href="https://emoji.gg/emoji/1044-babyyodasip"><img src="https://cdn3.emoji.gg/emojis/1044-babyyodasip.gif" width="40px" height="40px" alt="babyyodasip"></a>

# %% [markdown]
# Esse projeto tem como objetivo analisar a dinâmica das populações dos grupos de lobos e alces na Isle Royale, um parque nacional localizado no Michigan. O foco do projeto recai na exploração das complexas interações entre predadores e presas, por meio do uso do modelo de Lotka-Volterra. Além disso, serão avaliadas as projeções que emergem dessa relação, considerando as possíveis implicações resultantes de mudanças climáticas e intervenções humanas sobre as quantidades de indivíduos envolvidos, tendo resultados interessantes quando considerado o fator climático que beneficia os lobos e mantém o equilíbrio do sistema.

# %% [markdown]
# # Introdução <a href="https://emoji.gg/emoji/4549-spongebob-pageflip"><img src="https://cdn3.emoji.gg/emojis/4549-spongebob-pageflip.gif" width="60px" height="60px" alt="Spongebob_PageFlip"></a>

# %% [markdown]
# No cenário complexo dos ecossistemas naturais, as interações entre predadores e presas desempenham um papel fundamental na dinâmica e equilíbrio das populações. O presente projeto se dedica a uma análise aprofundada das dinâmicas populacionais entre grupos de lobos e alces na Isle Royale, um parque nacional situado no estado de Michigan. Por meio da aplicação do modelo de Lotka-Volterra, um instrumento analítico amplamente utilizado para compreender as relações entre predadores e presas, nosso estudo busca desvendar as conexões que moldam essas populações.
#
# A Isle Royale, abrigando uma intrigante teia de interações biológicas, proporciona um cenário ideal para investigar os padrões de comportamento das populações de lobos e alces. As dinâmicas entre esses dois grupos constituem um equilíbrio delicado, onde a densidade populacional de alces influencia diretamente o sucesso da população de lobos e, por sua vez, a pressão de predação dos lobos impacta as populações de alces. E tratando-se de um abiente controlado e relativamente pequeno, foi possivel se ter uma contagem exata do tamanho das populações ao decorrer do tempo.
#
# Entre 2011 e 2014 houve um grande decaimento da população de lobos que preocupou as autoridades locais, fazendo com que a população de lobos fosse aumentada de forma artificial para restaurar a dinâmica predador-presa dessas espécies. Apesar de acreditar-se que os lobos chegaram na ilha na década de 1940 através de um iceberg e estão lá a pouco tempo, eles possuem um papel importante para o equilíbrio do ecossistema e precisam ser preservados. Além disso, estudos apontam que lobos são beneficiados por invernos mais severos e locais com um maior acúmulo de neve, fazendo com que eles consigam caçar mais e mantenham o equilíbrio do sistema no inverno.
#
# Uma ênfase adicional deste projeto recai sobre a exploração das projeções decorrentes dessas relações complexas, considerando variáveis que vão além das interações puramente biológicas. Mudanças climáticas e intervenções humanas podem ter efeitos profundos nas quantidades de indivíduos envolvidos, desencadeando um efeito dominó que reverbera por toda a cadeia alimentar.
#
# O aumento da temperatura média do planeta, resultado direto das atividades humanas e das emissões de gases de efeito estufa, provoca uma série de impactos profundos e preocupantes. O derretimento acelerado das calotas polares e geleiras contribui para a elevação do nível do mar, ameaçando populações costeiras e ecossistemas sensíveis. Eventos climáticos extremos, como tempestades mais intensas e prolongadas ondas de calor, tornam-se mais frequentes e intensos, resultando em prejuízos econômicos, sociais e ambientais. A alteração nos padrões de precipitação afeta a disponibilidade de água potável e a produtividade agrícola, exacerbando riscos de escassez alimentar e hídrica. Além disso, o aquecimento global desencadeia desequilíbrios ecossistêmicos, causando perda de biodiversidade e impactando a saúde de ecossistemas terrestres e marinhos, podendo levar espécies a extinção.

# %% [markdown]
# # Objetivos 🎯

# %% [markdown]
# O presente estudo tem como objetivo a análise abrangente das dinâmicas populacionais das espécies de lobos e alces no Isle Royale National Park, no período de 1980 a 2019. O foco principal reside na investigação das interações interespecíficas entre predadores e presas, especificamente, como as relações entre lobos e alces são influenciadas por variáveis externas, com foco nas mudanças climáticas globais.
#
# A pesquisa emprega alguns métodos, incluindo análise de dados históricos, juntamente com técnicas de modelagem de equações diferenciais. Essas abordagens permitem uma compreensão mais profunda das tendências e padrões subjacentes nas interações entre as duas espécies ao longo do período de estudo.
#
# Será construido um modelo em python para analisar dados e projetar como as espécies se comportariam de maneira teórica (considerando apenas as interações entre as duas espécies), com auxílio das bibliotecas Scikit Learn, Numpy, Pandas e Matplotlib.
#
# Em síntese, o projeto visa entender como as relações interespecíficas de presa e predador podem ser afetadas por fatores externos e determinar o quão próximo da realidade é o modelo lotka-volterra para o estudo populacional de presas e predadores.

# %% [markdown]
# # Mapa mental <a href="https://emoji.gg/emoji/2537-codercat"><img src="https://w1.pngwing.com/pngs/233/753/png-transparent-map-treasure-hunting-buried-treasure-treasure-map-scavenger-hunt-piracy-joint-finger.png" width="50px" height="50px" alt="codercat"></a>

# %% [markdown]
# *link do mapa mental:* https://coggle.it/diagram/ZNGEk-ut86IrKyw_/t/o-impacto-do-aquecimento-global-na-isle-royale-national-park

# %% [markdown]
# # Modelo **(Lotka-Volterra)** <a href="https://emoji.gg/emoji/7867-predator"><img src="https://cdn3.emoji.gg/emojis/7867-predator.png" width="40px" height="40px" alt="Predator"></a>

# %% [markdown]
# No início do século XX, Alfred J. Lotka, um cientista americano, propôs pela primeira vez um modelo de interações predador-presa em 1920, inicialmente relacionado a reações químicas. Ele estendeu esse modelo para interações biológicas, explorando o crescimento de populações de presas e predadores. Paralelamente, Vito Volterra, um matemático italiano, também estava investigando dinâmicas semelhantes após observações de capturas de peixes. Em 1926, Volterra publicou um conjunto de equações semelhantes, reconhecendo a contribuição de Lotka. Devido a essas contribuições independentes, o modelo ficou conhecido como "modelo Lotka-Volterra".

# %% [markdown]
# O modelo Lotka-Volterra, também conhecido como Equações de Predador-Presa, é um par de equações diferenciais utilizadas para descrever a dinâmica de interações entre duas espécies em um ecossistema. Especificamente, o modelo descreve a relação entre uma espécie predadora e uma espécie presa ao longo do tempo.

# %% [markdown]
# A dinâmica dessas populações é governada pelas taxas de crescimento e interações entre elas. O modelo descreve um ciclo de feedback, no qual o aumento na população de presas leva a um aumento na população de predadores, que por sua vez reduz a população de presas, levando a uma redução na população de predadores, e assim por diante. Isso resulta em oscilações periódicas nas populações das duas espécies.

# %% [markdown]
# Vale ressaltar que o modelo Lotka-Volterra é uma simplificação da complexidade dos ecossistemas reais e não leva em consideração fatores como recursos limitados, outras interações entre espécies, migração, mudanças ambientais e outras nuances da ecologia.

# %% [markdown]
# No entanto, ele oferece uma base para entender como as interações entre predadores e presas podem influenciar suas populações ao longo do tempo.

# %% [markdown]
# O modelo básico consiste em duas equações diferenciais acopladas, uma para a população de predadores e outra para a população de presas:

# %% [markdown]
# $\dfrac{dx}{dt} = x * (α - β*y)$

# %% [markdown]
# $\dfrac{dy}{dt} = y * (-δ + γ*x)$

# %% [markdown]
# Onde:

# %% [markdown]
# x: população de presas\
# y: população de predadores\
# $α$: taxa de crescimento de presas sem predadores\
# $β$: taxa de decréscimo da população de presas devido a predação\
# $δ$: taxa de mortalidade de predadores sem presas\
# $γ$: taxa de crescimento de predadores devido a predação

# %% [markdown]
# De forma geral, tem-se um modelo com N espécies que interagem entre si:

# %% [markdown]
# $\dfrac{dy_i}{dt} = α_i * y_i + \sum_{j=1}^{N} β_{ij} * y_i * y_j$

# %% [markdown]
# Onde $y_i$ é a população da i-ésima espécie e $α_i$ é a taxa de crescimento da i-ésima espécie. Além disso, as espécies interagem entre si e essa relação é descrita através do parâmetro $β_{ij}$, que é a taxa em que essa relação afeta a população da i-ésima espécie.

# %% [markdown]
# Essas equações descrevem como as interações entre as populações de presas e predadores afetam seus respectivos crescimentos. Quando a população de presas aumenta, mais alimentos estão disponíveis para os predadores, o que leva ao aumento da população de predadores. No entanto, um aumento na população de predadores leva a uma maior pressão de predação sobre as presas, o que pode resultar em uma diminuição de sua população. Esse ciclo de interações leva a flutuações periódicas nas populações de ambas as espécies.

# %% [markdown]
# # Visualizando os dados <a href="https://emoji.gg/emoji/5309-stare"><img src="https://cdn3.emoji.gg/emojis/5309-stare.gif" width="55px" height="55px" alt="Stare"></a>

# %% [markdown]
# ### Importando as bibliotecas necessárias

# %%
import pandas as pd
import numpy as np
from scipy.integrate import odeint
import scipy.optimize
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# !git clone https://github.com/luanbezerra/climate-impact-predator-prey-populations.git
# Out:
# Cloning into 'climate-impact-predator-prey-populations'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 11 (delta 1), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# ### Leitura e tratamento de dados

# %%
#populações
data = pd.read_csv('climate-impact-predator-prey-populations/data/Planilha_sem_titulo_-_Pagina1 (1).csv')
#temperatura global
data_temp = pd.read_csv('climate-impact-predator-prey-populations/data/data_temp.csv')

#salvando os valores maximos e minimos para printar no final os valores desnormalizados
min = data.min()
max = data.max()

min_lobo = min['lobo']
max_lobo = max['lobo']
min_alce = min['alce']
max_alce = max['alce']

#normalizando os valores
scaler = MinMaxScaler()
data['lobo'] = scaler.fit_transform(data[['lobo']])
data['alce'] = scaler.fit_transform(data[['alce']])

#selecionando cada série
lobo = data.loc[:,"lobo"]
alce = data.loc[:,"alce"]
anos = data.loc[:,"ano"]
#agora para temperatura global
temp = data_temp.loc[:, "Anomaly"]
ano_temp = data_temp.loc[:, "Year"]

#trasnformando em listas
lobo = lobo.values.tolist()
alce = alce.values.tolist()
anos = anos.values.tolist()
temp = temp.values.tolist()
ano_temp = ano_temp.values.tolist()

# %% [markdown]
# ### Visualizando nossas informações em um gráfico para entender a dinâmica entre as populações através dos anos

# %%
#desnormalizando apenas para ajustar a escala do gráfico
for i in range (len(anos)):
  alce[i] = (alce[i] * (max_alce - min_alce)) + min_alce
  lobo[i] = (lobo[i] * (max_lobo - min_lobo)) + min_lobo

# %%
fig, ax1 = plt.subplots()

ax1.set_xlabel("ano")

ax1.set_ylabel("alce", color="red")
ax1.plot(anos, alce, '-', color = "red")
ax1.tick_params(axis='y', labelcolor="red")

ax2 = ax1.twinx()

ax2.set_ylabel("lobo", color="blue")
plt.plot(anos, lobo, '-', color = "blue")
ax2.tick_params(axis='y', labelcolor="blue")

plt.title('Gráfico 1')

fig.tight_layout()
plt.show()

# %%
#normalizando de volta
for i in range (len(anos)):
  alce[i] = (alce[i] - min_alce) / (max_alce - min_alce)
  lobo[i] = (lobo[i] - min_lobo) / (max_lobo - min_lobo)

# %% [markdown]
# ### <a href="https://emoji.gg/emoji/5309-stare"><img src="https://cdn3.emoji.gg/emojis/5309-stare.gif" width="40px" height="40px" alt="Stare"></a> Visualizando a varição de temperatura global

# %%
#nomeando os eixos
plt.xlabel("ano")
plt.ylabel("variação de temperatura (°C)")

#plotar grafico
plt.plot(ano_temp, temp, '-')
plt.title('Gráfico 2')
plt.show()

# %% [markdown]
# ## Modelagem das equações

# %% [markdown]
# ### Lotka-Volterra: modelando as equações

# %%
#modelo
def model(variables, t, params):

  #presas
  x = variables[0]
  #predadores
  y = variables[1]

  #parametros
  alpha, beta, delta, gamma = params;

  #equações
  dxdt = alpha * x - beta * x * y
  dydt = delta * x * y - gamma * y

  return([dxdt, dydt])

# %%
def loss_func(params, ano, alce, lobo):
    y0 = [alce[0], lobo[0]]

    t = np.linspace(ano[0], ano[-1],num=len(ano))

    output = odeint(model, y0, t, args=(params,))

    loss = 0

    for i in range(len(ano)):
        data_alce = alce[i]
        model_alce = output[i, 0]
        data_lobo = lobo[i]
        model_lobo = output[i,1]

        res = (data_alce - model_alce)**2 + (data_lobo - model_lobo)**2
        loss += res

    return loss

# %%
#definindo os parâmetros
params0 = np.array([1,1,1,1])
minimo = scipy.optimize.fmin(loss_func, params0, args=(anos, alce, lobo))
print(minimo)

alpha, beta, delta, gamma = minimo
params = np.array([alpha, beta, delta, gamma])
# Out:
# Optimization terminated successfully.
#          Current function value: 6.391214
#          Iterations: 286
#          Function evaluations: 498
# [0.42116252 1.09963448 3.23811362 0.6071812 ]

# %%
#valores iniciais das populações
y0 = [alce[0], lobo[0]] # [preys, predators]

#tempo
t = np.linspace(anos[0], anos[-1],num=len(anos))

# %%
#resolvendo as ODEs
y = odeint(model, y0, t, args=(params,))

# %%
for i in range (len(y)):
  y[i,0] = (y[i,0] * (max_alce - min_alce)) + min_alce
  y[i,1] = (y[i,1] * (max_lobo - min_lobo)) + min_lobo

# %%
#plotando os resultados num gráfico com a mesma escala
plt.plot(t, y[:,0], color = "red")
plt.plot(t, y[:,1], color = "blue")
plt.xlabel("tempo")
plt.ylabel("Alces e Lobos")
plt.legend(['Alces', 'Lobos'])
plt.title('Gráfico 3')
plt.show()

# %%
#agora utilizando escalas diferentes para analisar o comportamento das curvas
f, ax1 = plt.subplots()
ax1.set_xlabel("ano")
ax1.set_ylabel("alce", color="red")
ax1.plot(t, y[:,0], '-', color = "red")
ax1.tick_params(axis='y', labelcolor="red")

ax2 = ax1.twinx()

ax2.set_ylabel("lobo", color="blue")
plt.plot(t, y[:,1], '-', color = "blue")
ax2.tick_params(axis='y', labelcolor="blue")

f.tight_layout()
plt.title('Gráfico 4')
plt.show()

# %% [markdown]
# Agora será feito uma modelagem com os dados antes de um desequilibrio na população de lobos, que estava quase indo à extinção.

# %%
#selecionando cada série até 2010
lobo = data.loc[0:30,"lobo"]
alce = data.loc[0:30,"alce"]
anos = data.loc[0:30,"ano"]

#trasnformando em listas
lobo = lobo.values.tolist()
alce = alce.values.tolist()
anos = anos.values.tolist()

# %%
#definindo os parâmetros
params0 = np.array([1,1,1,1])
minimo = scipy.optimize.fmin(loss_func, params0, args=(anos, alce, lobo))
print(minimo)

alpha, beta, delta, gamma = minimo
params = np.array([alpha, beta, delta, gamma])
# Out:
# Optimization terminated successfully.
#          Current function value: 3.887870
#          Iterations: 222
#          Function evaluations: 379
# [0.56016861 1.14443416 0.99717944 0.25698186]

# %%
#valores iniciais das populações
y0 = [alce[0], lobo[0]] # [preys, predators]

#tempo
t = np.linspace(anos[0], anos[-1],num=len(anos))

# %%
#resolvendo as ODEs
y = odeint(model, y0, t, args=(params,))

# %%
for i in range (len(y)):
  y[i,0] = (y[i,0] * (max_alce - min_alce)) + min_alce
  y[i,1] = (y[i,1] * (max_lobo - min_lobo)) + min_lobo

# %%
#plotando os resultados num gráfico com a mesma escala
plt.plot(t, y[:,0], color = "red")
plt.plot(t, y[:,1], color = "blue")
plt.xlabel("tempo")
plt.ylabel("Alces e Lobos")
plt.legend(['Alces', 'Lobos'])
plt.title('Gráfico 5')
plt.show()

# %%
#agora utilizando escalas diferentes para analisar o comportamento das curvas
f, ax1 = plt.subplots()
ax1.set_xlabel("ano")
ax1.set_ylabel("alce", color="red")
ax1.plot(t, y[:,0], '-', color = "red")
ax1.tick_params(axis='y', labelcolor="red")

ax2 = ax1.twinx()

ax2.set_ylabel("lobo", color="blue")
plt.plot(t, y[:,1], '-', color = "blue")
ax2.tick_params(axis='y', labelcolor="blue")

f.tight_layout()
plt.title('Gráfico 6')
plt.show()

# %% [markdown]
# ## Resultados <a href="https://emoji.gg/emoji/8987-stitchthinking"><img src="https://cdn3.emoji.gg/emojis/8987-stitchthinking.gif" width="64px" height="64px" alt="Stitchthinking"></a>

# %% [markdown]
# Inicialmente, os dados das populações foram plotados para visualizar o comportamento desse sistema. Um ponto importante que foi destacado, é que a população de lobos sofreu um decaimento a partir de 2010 que levou a população a números insustentáveis, e após esse período houve um crescimento muito alto dessa população, porém, esse crescimento foi devido a uma inserção artificial de lobos no ecossistema para evitar a extinção dos lobos na ilha. E devido a queda da população de lobos nesse período, a população de alce teve um crescimento descontrolado, que obedece o modelo se retirarmos os predadores, e a taxa de crescimento das presas fica apenas em função da sua taxa de natalidade.
#
# Para um melhor ajuste dos parâmetros, todos os dados das populações foram normalizados em valores entre 0 e 1. O modelo teve seus parâmetros ajustados utilizando todos os dados das populações e assim os resultados obtidos (gráfico 4) se mostraram melhores que os obtidos anteriormente, porém, apresentaram o mesmo problema com a periodicidade e uma variação no número das populações. Então, esse resultado não foi considerado confiável.
#
# A partir do gráfico 2 foi possível notar uma variação da temperatura muito maior a partir de 2010, que também foi o mesmo período onde houve um desbalanceamento na população de lobos, e como os lobos são beneficiados pelo inverno, uma nova abordagem foi utilizada, apenas os dados até 2010 foram utilizados para ajustar os parâmetros, e assim foi obtido o resultado mostrado no gráfico 6. Analisando esse resultado, é possível observar que houve uma melhora na periodicidade, se aproximando do comportamento real, mas ainda existe uma discrepância nos valores para a população e lobos. Em geral, mostrou uma melhora em relação ao gráfico 4.

# %% [markdown]
# ## Conclusão <a href="https://emoji.gg/emoji/2537-codercat"><img src="https://cdn3.emoji.gg/emojis/2537-codercat.gif" width="50px" height="50px" alt="codercat"></a>

# %% [markdown]
# O modelo Lotka-Volterra, apesar de ter uma significante contribuição para o estudo da ecologia, demonstrando as relações ecológicas entre predadores e presas, possui limitações ao ser aplicado na realidade, pois há inúmeros fatores que podem influenciar na dinâmica populacional, como as mudanças climáticas, interações com outras espécies, limite de recursos, entre outros fatores ecológicos. O modelo desenvolvido conseguiu aproximar a periodicidade de crescimento das populações, mas com um erro nos valores das populações, que podem estar associados a fatores não considerados pelo modelo. Um ponto importante nesse sistema é o fator climático, já que o inverno e locais com mais acúmulo de neve beneficiam os lobos na caça aos alces, assim, o aquecimento global tem um grande potencial para interferir nesse sistemas, e como a variação de temperatura a cada ano está cada vez maior, a existência de ecossistemas como esse fica ameaçada.

# %% [markdown]
# ## Referências

# %% [markdown]
# [1] "Lion, wildebeest and zebra: A predator-prey model". Disponível em: http://people.kzoo.edu/barth/math280/articles/lion_wildebeest_zebra.pdf \
# [2] "Parametric identification of the model with one predator and two prey species". Disponível em: https://www.researchgate.net/publication/30511506_Parametric_identification_of_the_model_with_one_predator_and_two_prey_species \
# [3] "Modelo de Lotka-Volterra". Disponível em: https://fiscomp.if.ufrgs.br/index.php/Modelo_de_Lotka-Volterra \
# [4] "Determination of the parameters in lotka-volterra equations from population measurements - algorithms and numerical experiments". Disponível em: https://www.siam.org/Portals/0/Documents/S138316PDF.pdf?ver=2021-08-20-064902-210 \
# [5] "Wolf and moose population". Disponível em: https://www.nps.gov/isro/learn/nature/wolf-moose-populations.htm \
# [6] "Python code for predator-prey model". Disponível em: https://www.youtube.com/watch?v=2f5aRTBmm10 \
# [7] "Fitting the predator-prey model to data". Disponível em: https://www.youtube.com/watch?v=0jgGbCM7dXk&t=1286s \
# [8] "The role of weather and long-term prey dynamics as drivers of wolf population dynamics in a multi-prey system". Disponível em: https://www.frontiersin.org/articles/10.3389/fevo.2022.791161/full \
# [9] "The population biology of Isle Royale wolves and moose: An overview". Disponível em: https://isleroyalewolf.org/data/data/home.html
